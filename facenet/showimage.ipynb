# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
imgraw_path="/wk/tf_base/facenet/lfw/raw/Abdullah_Gul/Abdullah_Gul_0001.jpg"
img160_path="/wk/tf_base/facenet/lfw/lfw_mtcnnpy_160/Abdullah_Gul/Abdullah_Gul_0001.png"

# %%
img = cv2.imread(img160_path)
img = img[:,:,::-1] # 必须为 ::-1
plt.imshow(img)

# %%
img = cv2.imread(imgraw_path)
img = img[:,:,::-1] # 必须为 ::-1
plt.imshow(img)

# %%
exp_imgraw_path="/wk/tf_base/facenet/CASIA-WebFace/raw/0000099/052.jpg"
img160_path="/wk/tf_base/facenet/lfw/lfw_mtcnnpy_160/Abdullah_Gul/Abdullah_Gul_0001.png"

# %%
img = cv2.imread(exp_imgraw_path)
img = img[:,:,::-1] # 必须为 ::-1
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (250, 250, 3)
